# %% [markdown]
# <a href="https://colab.research.google.com/github/Arjx01/ML_LAB/blob/main/ML_Final1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from sklearn.linear_model import Ridge, Lasso

# %%
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("house_price.csv")

# %%
X = data[['area']]
y = data['price']

# %%
ridge = Ridge(alpha=1.0)
ridge.fit(X, y)
ridge_pred = ridge.predict(X)

# %%
lasso = Lasso(alpha=1.0)
lasso.fit(X, y)
lasso_pred = lasso.predict(X)

# %%
ridge_mse = mean_squared_error(y, ridge_pred)
lasso_mse = mean_squared_error(y, lasso_pred)

# %%
print("Ridge MSE:", ridge_mse)
print("Lasso MSE:", lasso_mse)
# Out:
# Ridge MSE: 2488861398180.6567
# Lasso MSE: 2488861398180.6577

# %%
print("Ridge Coefficient:", ridge.coef_)
print("Lasso Coefficient:", lasso.coef_)
# Out:
# Ridge Coefficient: [461.97489409]
# Lasso Coefficient: [461.97489406]
